# %% [markdown]
# #**Let's Grow More - VIP**

# %% [markdown]
# #**Sufiyan Sayed**

# %% [markdown]
# ###**Task 2 : Image to Pencil sketch Converssion**
# Image: [Dr.Stone](https://2.bp.blogspot.com/-zF3VSZRy0_0/XSJuGWm2g4I/AAAAAAAAIN4/LvG29SBSU7QdnsL0lLwdXCMnIKhsoP96wCKgBGAs/w0/dr-stone-senku-ishigami-uhdpaper.com-4K-27.jpg)

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/external-content.duckduckgo.com.jpeg")
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img.shape
# Out:
# (1090, 2500, 3)

# %%
resized = cv2.resize(img,(622,350),3)
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=622x350 at 0x7FDCC29D9510>

# %%
gray = cv2.cvtColor(resized,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=622x350 at 0x7FDCC29E28D0>

# %%
inverted_gray = 255-gray
cv2_imshow(inverted_gray)
# Out:
# <PIL.Image.Image image mode=L size=622x350 at 0x7FDCC29EEE10>

# %%
blur = cv2.GaussianBlur(inverted_gray,(21,21),0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=622x350 at 0x7FDCC29EE210>

# %%
inverted_blur = 255-blur 
cv2_imshow(inverted_blur)
# Out:
# <PIL.Image.Image image mode=L size=622x350 at 0x7FDCC197F150>

# %%
sketch = cv2.divide(gray,inverted_blur,scale=256.0)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=622x350 at 0x7FDCC29F1BD0>
